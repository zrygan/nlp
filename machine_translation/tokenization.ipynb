# %% [markdown]
# # Resource Checking
# Check if the necessary resources are available for this notebook.

# %%
# !nvidia-smi -L
# Out:
# Running cells with 'Python 3.13.3' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/bin/python -m pip install ipykernel -U --user --force-reinstall'
